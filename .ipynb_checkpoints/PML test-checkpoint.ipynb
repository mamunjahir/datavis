# %%
import pandas as pd

# %%
df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data',"sep='\s+'","header='None'",engine='python');

# %%
df.columns=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-f35f5a16bb1c> in <module>
# ----> 1 df.columns=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# ...

# %%
print(df.columns)
# Out:
# Index(['0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00'], dtype='object')

# %%
columns_header = [th.getText().rstrip() for th in table.findAll('tr')[0].findAll('th')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-09fcde8f40c7> in <module>
# ----> 1 columns_header = [th.getText().rstrip() for th in table.findAll('tr')[0].findAll('th')]
#
# NameError: name 'table' is not defined

# %%
df.columns
# Out:
# Index([' 0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00'], dtype='object')

# %%
df=pd.read_csv('energydata_complete.csv')

# %%
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# 5      2016-01-11 17:50:00          50      40  19.890000  46.026667
# 6      2016-01-11 18:00:00          60      50  19.890000  45.766667
# 7      2016-01-11 18:10:00          60      50  19.856667  45.560000
# 8      2016-01-11 18:20:00          60      40  19.790000  45.597500
# 9      2016-01-11 18:30:00          70      40  19.856667  46.090000
# 10     2016-01-11 18:40:00         230      70  19.926667  45.863333
# 11     2016-01-11 18:50:00         580      60  20.066667  46.396667
# 12     2016-01-11 19:00:00         430      50  20.133333  48.000000
# ...

# %%
df.head(n=2)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2     RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.7900
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.7225
#
#       T3   RH_3    T4    ...             T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.73  19.0    ...      17.033333  45.53  6.600000        733.5
# 1  19.79  44.79  19.0    ...      17.066667  45.56  6.483333        733.6
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
#
# [2 rows x 29 columns]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set(style='whitegrid',context='notebook')

# %%
cols=['T1','RH_1','T2','RH_2'];
